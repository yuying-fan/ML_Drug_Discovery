# %% [markdown]
# # 0. Set up environment for the project
# Run the cells in a **terminal** once, before opening the other notebooks. Then point your editor's kernel at the `ml_drug_discovery` environment.

# %%
# create env
conda create -n ml_drug_discovery -c conda-forge python=3.11 -y

# activate
conda activate ml_drug_discovery

# install packages (conda-forge)
conda install -c conda-forge numpy pandas scipy scikit-learn matplotlib seaborn altair rdkit umap-learn hdbscan xgboost catboost pyarrow gdown jupyter ipykernel tqdm pillow more-itertools pympler -y

# torch (for the DANN domain-adaptation experiment) and tabpfn isn't on conda-forge -> pip into env (pulls in PyTorch)
pip install torch tabpfn

# In case can't find as kernel in VSCode, register:
## python -m ipykernel install --user --name ml_drug_discovery --display-name "ml_drug_discovery"

# %%
# after setting up the env and finishing all notebooks, captured for reproducibility / sharing:
conda env export --from-history > environment.yml
pip freeze > requirements.txt
